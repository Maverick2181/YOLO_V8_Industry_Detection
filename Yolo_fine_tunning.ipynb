# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.8/486.8 KB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 11.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]

# %%
# Use the model
model.train(data="/content/drive/MyDrive/PJT - Computer Vision/Dataset/all_valve/data.yaml", epochs=1)  # train the model
# Out:
# Ultralytics YOLOv8.0.57 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# ...

# %%
metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.57 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/PJT - Computer Vision/Dataset/all_valve/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7/7 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
#                    all          7          7    0.00339          1      0.231      0.122
#            close_valve          7          4    0.00411          1      0.108     0.0316
#             open_valve          7          3    0.00266          1      0.353      0.212
# Speed: 2.6ms preprocess, 216.7ms inference, 0.0ms loss, 16.7ms postprocess per image
# Results saved to runs/detect/val

# %%
results = model("/content/drive/MyDrive/PJT - Computer Vision/Dataset/all_valve/valid/images/close1_jpeg.rf.aedce55bc918af7dd480d1394ec0a08d.jpg")  # predict on an image

# %%
from google.colab import files

# %%
files.download('/content/runs/detect/val')
